# %%
# Welcome to Ex2C Lab2!

# %%
def favorite_things(name,movie,music):
    return f"My name is {name}.\nMy favorite movie is {movie}.\nMy favorite musician/band is {music}."

print(favorite_things("Fuat", "John Wick", "Tame Impala"))
# Out:
# My name is Fuat.
# My favorite movie is John Wick.
# My favorite musician/band is Tame Impala.

# %%
def why_im_here(purpose):
    return purpose

print(why_im_here("Earning real-world experience is better than structured school programs."))
# Out:
# Earning real-world experience is better than structured school programs.

# %%
def favorite_place(place,why):
    return f"One of my favorite places is {place} because {why}"

# %%
print(favorite_place("Izmir","it is such a nice place to live in."))
# Out:
# One of my favorite places is Izmir because it is such a nice place to live in.

# %%
print(favorite_place("San Diego","it is an USA version of Izmir"))
# Out:
# One of my favorite places is San Diego because it is an USA version of Izmir
